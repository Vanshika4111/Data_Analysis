# %% [markdown]
# # import pandas

# %%
import pandas as pd

# %% [markdown]
# # importing data

# %%
names=["id","title","year","rating","votes","length","genre"]
data = pd.read_csv('imdb_top_10000.txt',sep='\t',names=names,index_col=0)
#data.head()

# %% [markdown]
# # exploring data

# %%
data.head(1)
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
#
#                  genre
# id
# tt0111161  Crime|Drama

# %%
data.tail()
# Out:
#                                    title  year  rating  votes     length  \
# id
# tt0807721                 Meduzot (2007)  2007     7.0   1357   78 mins.
# tt0339642          Daltry Calhoun (2005)  2005     5.2   1357  100 mins.
# tt0060880  The Quiller Memorandum (1966)  1966     6.5   1356  104 mins.
# tt0152836                    Taal (1999)  1999     6.5   1356  179 mins.
# tt0279977          The Navigators (2001)  2001     6.9   1356   96 mins.
#
#                                 genre
# id
# tt0807721                       Drama
# tt0339642  Comedy|Drama|Music|Romance
# tt0060880      Drama|Mystery|Thriller
# tt0152836             Musical|Romance
# tt0279977                Comedy|Drama

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, tt0111161 to tt0279977
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   10000 non-null  object
#  1   year    10000 non-null  int64
#  2   rating  10000 non-null  float64
#  3   votes   10000 non-null  int64
#  4   length  10000 non-null  object
#  5   genre   9999 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 546.9+ KB

# %%
data.describe()
# Out:
#                year        rating          votes
# count  10000.000000  10000.000000   10000.000000
# mean    1993.472800      6.386070   16604.012800
# std       14.829924      1.189933   34563.459698
# min     1950.000000      1.500000    1356.000000
# 25%     1986.000000      5.700000    2333.750000
# 50%     1998.000000      6.600000    4980.500000
# 75%     2005.000000      7.200000   15277.750000
# max     2011.000000      9.200000  619479.000000

# %% [markdown]
# # exporting data

# %%
data.to_csv("test.csv",header=True,index=True,sep=",")

# %% [markdown]
# # sorting data

# %%
data.sort_values(by="rating")
# Out:
#                                            title  year  rating   votes  \
# id
# tt0270846    Superbabies: Baby Geniuses 2 (2004)  2004     1.5   13196
# tt0059464                 Monster a-Go Go (1965)  1965     1.5    3255
# tt0364986                    Ben & Arthur (2002)  2002     1.5    4675
# tt0421051               Daniel the Wizard (2004)  2004     1.5    8271
# tt1309000                      Dream Well (2009)  2009     1.5    2848
# ...                                          ...   ...     ...     ...
# tt0071562          The Godfather: Part II (1974)  1974     9.0  291169
# tt0060196  The Good, the Bad and the Ugly (1966)  1966     9.0  195238
# tt0110912                    Pulp Fiction (1994)  1994     9.0  490065
# tt0068646                   The Godfather (1972)  1972     9.2  474189
# tt0111161        The Shawshank Redemption (1994)  1994     9.2  619479
#
#               length                               genre
# id
# ...

# %%
data.sort_values(by="rating",ascending=False)
# Out:
#                                            title  year  rating   votes  \
# id
# tt0111161        The Shawshank Redemption (1994)  1994     9.2  619479
# tt0068646                   The Godfather (1972)  1972     9.2  474189
# tt0060196  The Good, the Bad and the Ugly (1966)  1966     9.0  195238
# tt0110912                    Pulp Fiction (1994)  1994     9.0  490065
# tt0252487                Outrageous Class (1975)  1975     9.0    9823
# ...                                          ...   ...     ...     ...
# tt0364986                    Ben & Arthur (2002)  2002     1.5    4675
# tt0060753       Night Train to Mundo Fine (1966)  1966     1.5    3542
# tt0421051               Daniel the Wizard (2004)  2004     1.5    8271
# tt0059464                 Monster a-Go Go (1965)  1965     1.5    3255
# tt0060666        Manos: The Hands of Fate (1966)  1966     1.5   20927
#
#               length                               genre
# id
# ...

# %% [markdown]
# # Creating data frames from scratch

# %%
sample_data={
    "number":[22,23,45,23],
    "rollno":[1,2,3,4],
    "standard":["I","II","III","IV"]
}

# %%
data_2=pd.DataFrame(sample_data)

# %%
data_2
# Out:
#    number  rollno standard
# 0      22       1        I
# 1      23       2       II
# 2      45       3      III
# 3      23       4       IV

# %%
del data_2

# %%
data_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data_2
#
# NameError: name 'data_2' is not defined

# %% [markdown]
# # Selecting Data

# %%
data["title"]
# Out:
# id
# tt0111161    The Shawshank Redemption (1994)
# tt0110912                Pulp Fiction (1994)
# tt0137523                  Fight Club (1999)
# tt0133093                  The Matrix (1999)
# tt1375666                   Inception (2010)
#                           ...
# tt0807721                     Meduzot (2007)
# tt0339642              Daltry Calhoun (2005)
# tt0060880      The Quiller Memorandum (1966)
# tt0152836                        Taal (1999)
# tt0279977              The Navigators (2001)
# Name: title, Length: 10000, dtype: object

# %%
data[["title","rating"]]
# Out:
#                                      title  rating
# id
# tt0111161  The Shawshank Redemption (1994)     9.2
# tt0110912              Pulp Fiction (1994)     9.0
# tt0137523                Fight Club (1999)     8.8
# tt0133093                The Matrix (1999)     8.7
# tt1375666                 Inception (2010)     8.9
# ...                                    ...     ...
# tt0807721                   Meduzot (2007)     7.0
# tt0339642            Daltry Calhoun (2005)     5.2
# tt0060880    The Quiller Memorandum (1966)     6.5
# tt0152836                      Taal (1999)     6.5
# tt0279977            The Navigators (2001)     6.9
#
# [10000 rows x 2 columns]

# %%
data["rating"].min()
# Out:
# 1.5

# %%
data["year"].mean()
# Out:
# 1993.4728

# %%
data["rating"].max()
# Out:
# 9.2

# %%
data["rating"].value_counts()
# Out:
# 7.1    401
# 6.8    401
# 7.2    386
# 6.7    384
# 7.0    382
#       ...
# 1.5      7
# 1.6      6
# 8.9      5
# 9.0      4
# 9.2      2
# Name: rating, Length: 77, dtype: int64

# %%
data["title"].unique()
# Out:
# array(['The Shawshank Redemption (1994)', 'Pulp Fiction (1994)',
#        'Fight Club (1999)', ..., 'The Quiller Memorandum (1966)',
#        'Taal (1999)', 'The Navigators (2001)'], dtype=object)

# %%
data["genre"].unique()
# Out:
# array(['Crime|Drama', 'Crime|Thriller', 'Drama|Mystery|Thriller', ...,
#        'Drama|War|Adventure|Romance', 'Western|Sci-Fi|Thriller',
#        'Adventure|Comedy|Drama|War'], dtype=object)

# %%
data["rating"].value_counts().sort_index()
# Out:
# 1.5     7
# 1.6     6
# 1.7    12
# 1.8    12
# 1.9     9
#        ..
# 8.7    13
# 8.8     9
# 8.9     5
# 9.0     4
# 9.2     2
# Name: rating, Length: 77, dtype: int64

# %%
data["rating"].value_counts().sort_index(ascending=False)
# Out:
# 9.2     2
# 9.0     4
# 8.9     5
# 8.8     9
# 8.7    13
#        ..
# 1.9     9
# 1.8    12
# 1.7    12
# 1.6     6
# 1.5     7
# Name: rating, Length: 77, dtype: int64

# %% [markdown]
# # Plotting

# %%
# %matplotlib inline

# %%
data.plot()
# Out:
# <AxesSubplot: xlabel='id'>

# %%
data.plot(kind="scatter",x="rating",y="votes")
# Out:
# C:\Users\vanshika Sharma\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='rating', ylabel='votes'>

# %%
data.plot(kind="scatter",x="rating",y="votes",alpha=0.3)
# Out:
# <AxesSubplot: xlabel='rating', ylabel='votes'>

# %%
data["rating"].plot(kind="hist")#,alpha=0.4)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
import seaborn as sns

# %%
sns.lmplot(x="rating",y="votes",data=data)

# %%
sns.pairplot(data)

# %% [markdown]
# # Linear least Square(OLS) Regression

# %%
import statsmodels.api as sm

# %%
results=sm.OLS(data["votes"],data["rating"]).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  votes   R-squared (uncentered):                   0.221
# Model:                            OLS   Adj. R-squared (uncentered):              0.220
# Method:                 Least Squares   F-statistic:                              2829.
# Date:                Fri, 20 Jan 2023   Prob (F-statistic):                        0.00
# Time:                        19:37:28   Log-Likelihood:                     -1.1849e+05
# No. Observations:               10000   AIC:                                  2.370e+05
# Df Residuals:                    9999   BIC:                                  2.370e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Advanced Data Selection

# %%
data["year"]
# Out:
# id
# tt0111161    1994
# tt0110912    1994
# tt0137523    1999
# tt0133093    1999
# tt1375666    2010
#              ...
# tt0807721    2007
# tt0339642    2005
# tt0060880    1966
# tt0152836    1999
# tt0279977    2001
# Name: year, Length: 10000, dtype: int64

# %%
data[data["year"]>1999]
# Out:
#                               title  year  rating   votes     length  \
# id
# tt1375666          Inception (2010)  2010     8.9  385149  148 mins.
# tt0499549             Avatar (2009)  2009     8.1  336855  162 mins.
# tt0372784      Batman Begins (2005)  2005     8.3  316613  140 mins.
# tt0266697  Kill Bill: Vol. 1 (2003)  2003     8.2  272983  111 mins.
# tt0416449                300 (2006)  2006     7.8  269328  117 mins.
# ...                             ...   ...     ...     ...        ...
# tt0339727          Stateside (2004)  2004     5.8    1358   97 mins.
# tt0218581       Scarlet Diva (2000)  2000     5.2    1358   91 mins.
# tt0807721            Meduzot (2007)  2007     7.0    1357   78 mins.
# tt0339642     Daltry Calhoun (2005)  2005     5.2    1357  100 mins.
# tt0279977     The Navigators (2001)  2001     6.9    1356   96 mins.
#
#                                       genre
# id
# tt1375666  Action|Adventure|Sci-Fi|Thriller
# ...

# %%
data["year"]>1999
# Out:
# id
# tt0111161    False
# tt0110912    False
# tt0137523    False
# tt0133093    False
# tt1375666     True
#              ...
# tt0807721     True
# tt0339642     True
# tt0060880    False
# tt0152836    False
# tt0279977     True
# Name: year, Length: 10000, dtype: bool

# %%
data[data["year"]==2000]
# Out:
#                                 title  year  rating   votes     length  \
# id
# tt0172495            Gladiator (2000)  2000     8.4  334107  155 mins.
# tt0209144              Memento (2000)  2000     8.7  325663  113 mins.
# tt0208092              Snatch. (2000)  2000     8.3  208975  104 mins.
# tt0180093  Requiem for a Dream (2000)  2000     8.5  220783  102 mins.
# tt0120903                X-Men (2000)  2000     7.4  141858  104 mins.
# ...                               ...   ...     ...     ...        ...
# tt0151150                 Josh (2000)  2000     5.7    1376  162 mins.
# tt0203940              Spiders (2000)  2000     3.7    1373   94 mins.
# tt0248409       No More School (2000)  2000     6.1    1380   99 mins.
# tt0177650          Company Man (2000)  2000     5.1    1358   95 mins.
# tt0218581         Scarlet Diva (2000)  2000     5.2    1358   91 mins.
#
#                                   genre
# id
# tt0172495        Action|Adventure|Drama
# ...

# %%
data[(data["year"]>1999) & (data["year"]<2005)]
# Out:
#                                                        title  year  rating  \
# id
# tt0266697                           Kill Bill: Vol. 1 (2003)  2003     8.2
# tt0120737  The Lord of the Rings: The Fellowship of the R...  2001     8.8
# tt0167260  The Lord of the Rings: The Return of the King ...  2003     8.8
# tt0167261       The Lord of the Rings: The Two Towers (2002)  2002     8.7
# tt0172495                                   Gladiator (2000)  2000     8.4
# ...                                                      ...   ...     ...
# tt0263124                                  Brainstorm (2001)  2001     7.8
# tt0368259                 Sex Lives of the Potato Men (2004)  2004     4.3
# tt0339727                                   Stateside (2004)  2004     5.8
# tt0218581                                Scarlet Diva (2000)  2000     5.2
# tt0279977                              The Navigators (2001)  2001     6.9
#
#             votes     length                           genre
# ...

# %%
data[(data["year"]>1999) | (data["year"]<2005)]
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
# ...                                    ...   ...     ...     ...        ...
# tt0807721                   Meduzot (2007)  2007     7.0    1357   78 mins.
# tt0339642            Daltry Calhoun (2005)  2005     5.2    1357  100 mins.
# tt0060880    The Quiller Memorandum (1966)  1966     6.5    1356  104 mins.
# tt0152836                      Taal (1999)  1999     6.5    1356  179 mins.
# tt0279977            The Navigators (2001)  2001     6.9    1356   96 mins.
#
#                                       genre
# id
# ...

# %%
data[(data["year"]>1999) & (data["year"]<2005)].sort_values(by="rating",ascending=False).head(10)
# Out:
#                                                        title  year  rating  \
# id
# tt0317248                                 City of God (2002)  2002     8.8
# tt0167260  The Lord of the Rings: The Return of the King ...  2003     8.8
# tt0120737  The Lord of the Rings: The Fellowship of the R...  2001     8.8
# tt0209144                                     Memento (2000)  2000     8.7
# tt0167261       The Lord of the Rings: The Two Towers (2002)  2002     8.7
# tt0245429                               Spirited Away (2001)  2001     8.6
# tt0180093                         Requiem for a Dream (2000)  2000     8.5
# tt0253474                                 The Pianist (2002)  2002     8.5
# tt0211915                                   Am\xe9lie (2001)  2001     8.5
# tt0338013       Eternal Sunshine of the Spotless Mind (2004)  2004     8.5
#
#             votes     length                               genre
# id
# tt0317248  199917  130 mins.                         Crime|Drama
# ...

# %% [markdown]
# # Grouping

# %%
data.groupby(["year"])["rating"].mean()
# Out:
# year
# 1950    7.545161
# 1951    7.478125
# 1952    7.475676
# 1953    7.106383
# 1954    7.371795
#           ...
# 2007    6.303831
# 2008    6.275260
# 2009    6.287290
# 2010    6.340635
# 2011    6.357143
# Name: rating, Length: 62, dtype: float64

# %%
data.groupby(["year"])["votes"].max()
# Out:
# year
# 1950     64363
# 1951     40104
# 1952     63655
# 1953     36760
# 1954    137663
#          ...
# 2007    237275
# 2008    555122
# 2009    336855
# 2010    385149
# 2011     72810
# Name: votes, Length: 62, dtype: int64

# %% [markdown]
# # Cleaning Data

# %%
data["title"].str[:-7]
# Out:
# id
# tt0111161    The Shawshank Redemption
# tt0110912                Pulp Fiction
# tt0137523                  Fight Club
# tt0133093                  The Matrix
# tt1375666                   Inception
#                        ...
# tt0807721                     Meduzot
# tt0339642              Daltry Calhoun
# tt0060880      The Quiller Memorandum
# tt0152836                        Taal
# tt0279977              The Navigators
# Name: title, Length: 10000, dtype: object

# %%
data["formatted title"]=data["title"].str[:-7]

# %%
data.head(5)
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                       genre           formatted title
# id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception

# %%
data["title"].str.split(' \(').str[0]
# Out:
# id
# tt0111161    The Shawshank Redemption
# tt0110912                Pulp Fiction
# tt0137523                  Fight Club
# tt0133093                  The Matrix
# tt1375666                   Inception
#                        ...
# tt0807721                     Meduzot
# tt0339642              Daltry Calhoun
# tt0060880      The Quiller Memorandum
# tt0152836                        Taal
# tt0279977              The Navigators
# Name: title, Length: 10000, dtype: object

# %%
data["formatted title"]=data["title"].str.split(' \(').str[0]

# %%
data.head(7)
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
# tt0109830              Forrest Gump (1994)  1994     8.7  368994  142 mins.
# tt0169547           American Beauty (1999)  1999     8.6  338332  122 mins.
#
#                                       genre           formatted title
# id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# ...

# %%
data["length"].str[:-6]
# Out:
# id
# tt0111161    142
# tt0110912    154
# tt0137523    139
# tt0133093    136
# tt1375666    148
#             ...
# tt0807721     78
# tt0339642    100
# tt0060880    104
# tt0152836    179
# tt0279977     96
# Name: length, Length: 10000, dtype: object

# %%
# second way

# %%
data["length"].str.split().str[0]
# Out:
# id
# tt0111161    142
# tt0110912    154
# tt0137523    139
# tt0133093    136
# tt1375666    148
#             ...
# tt0807721     78
# tt0339642    100
# tt0060880    104
# tt0152836    179
# tt0279977     96
# Name: length, Length: 10000, dtype: object

# %%
data["length"].str.split().str[0].astype("int")
# Out:
# id
# tt0111161    142
# tt0110912    154
# tt0137523    139
# tt0133093    136
# tt1375666    148
#             ...
# tt0807721     78
# tt0339642    100
# tt0060880    104
# tt0152836    179
# tt0279977     96
# Name: length, Length: 10000, dtype: int32

# %%
# third way

# %%
data["length"].str.replace("mins.","").astype("int")
# Out:
# C:\Users\vanshika Sharma\AppData\Local\Temp\ipykernel_20608\3952088988.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["length"].str.replace("mins.","").astype("int")
# id
# tt0111161    142
# tt0110912    154
# tt0137523    139
# tt0133093    136
# tt1375666    148
#             ...
# tt0807721     78
# tt0339642    100
# tt0060880    104
# tt0152836    179
# tt0279977     96
# Name: length, Length: 10000, dtype: int32

# %%
data["formatted length"]=data["length"].str.replace("mins.","").astype("int")
# Out:
# C:\Users\vanshika Sharma\AppData\Local\Temp\ipykernel_20608\657287770.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["formatted length"]=data["length"].str.replace("mins.","").astype("int")

# %%
data.head(5)
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                       genre           formatted title  \
# id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception
#
#            formatted length
# id
# tt0111161               142
# ...

# %%
sns.pairplot(data)

# %%
data[data["length"]==0]
# Out:
# Empty DataFrame
# Columns: [title, year, rating, votes, length, genre, formatted title, formatted length]
# Index: []
